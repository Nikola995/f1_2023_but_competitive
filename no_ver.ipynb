# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [F1 2023 without Max Verstappen](#toc1_)
#   - [Britain Sprint Results](#toc1_1_)
#   - [Britain Race Results](#toc1_2_)
#   - [Driver Standings After Last Race (Britain)](#toc1_3_)
#     - [Drivers Championship Timeline](#toc1_3_1_)
#   - [Constructors Standings After Last Race (Britain)](#toc1_4_)
#     - [Constructors Standings Timeline](#toc1_4_1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[F1 2023 without Max Verstappen](#toc0_)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utils
import plots

remove_drivers = ['VER']
remove_constructors = []
last_round = 10

# %% [markdown]
# ## <a id='toc1_1_'></a>[Britain Sprint Results](#toc0_)

# %%
utils.sprint_results(remove_drivers, last_round)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## <a id='toc1_2_'></a>[Britain Race Results](#toc0_)

# %%
race_results, fastest_lap = utils.race_results(remove_drivers, last_round)
display(race_results)
utils.print_fastest_lap(fastest_lap)
# Out:
#      No           Driver     Constructor  Laps  Points
# Pos
# 1     4     Lando Norris         McLaren    52      26
# 2    44   Lewis Hamilton        Mercedes    52      18
# 3    81    Oscar Piastri         McLaren    52      15
# 4    63   George Russell        Mercedes    52      12
# 5    11     Sergio Pérez        Red Bull    52      10
# 6    14  Fernando Alonso    Aston Martin    52       8
# 7    23  Alexander Albon        Williams    52       6
# 8    16  Charles Leclerc         Ferrari    52       4
# 9    55     Carlos Sainz         Ferrari    52       2
# 10    2   Logan Sargeant        Williams    52       1
# 11   77  Valtteri Bottas      Alfa Romeo    52       0
# 12   27  Nico Hülkenberg    Haas F1 Team    52       0
# 13   18     Lance Stroll    Aston Martin    52       0
# 14   24      Guanyu Zhou      Alfa Romeo    52       0
# 15   22     Yuki Tsunoda      AlphaTauri    52       0
# 16   21    Nyck de Vries      AlphaTauri    52       0
# DNF  10     Pierre Gasly  Alpine F1 Team    46       0
# DNF  20  Kevin Magnussen    Haas F1 Team    31       0
# DNF  31     Esteban Ocon  Alpine F1 Team     9       0
# Fastest lap: Lando Norris (McLaren) - 1:30.543 (lap 43)

# %% [markdown]
# ## <a id='toc1_3_'></a>[Driver Standings After Last Race (Britain)](#toc0_)

# %%
drivers_df = utils.drivers_standings(remove_drivers, last_round)
drivers_df
# Out:
#     No           Driver  BAH  SAU  AUS  AZE_SPR  AZE  MIA  MON  SPA  CAN  \
# 1   11     Sergio Pérez   25   26   13        8   25   25    0   16   11
# 2   14  Fernando Alonso   18   18   18        4   15   19   25    8   25
# 3   44   Lewis Hamilton   12   12   25        3   10   10   16   25   18
# 4   55     Carlos Sainz   15   10    0        5   12   12    6   12   12
# 5   63   George Russell    8   15    0        6    7   15   12   18    0
# 6   16  Charles Leclerc    0    8    0        7   18    8   10    1   15
# 7    4     Lando Norris    0    0   10        0    4    0    4    0    0
# 8   18     Lance Stroll   10    0   15        2    8    0    0   10    4
# 9   31     Esteban Ocon    0    6    0        0    0    4   18    6    6
# 10  10     Pierre Gasly    4    4    0        0    0    6    8    2    0
# 11  81    Oscar Piastri    0    0    6        0    1    0    2    0    1
# 12  23  Alexander Albon    2    0    0        1    0    0    0    0    8
# 13  27  Nico Hülkenberg    0    0    8        0    0    0    0    0    0
# 14  77  Valtteri Bottas    6    0    1        0    0    0    1    0    2
# 15  24      Guanyu Zhou    0    0    4        0    0    0    0    4    0
# 16  22     Yuki Tsunoda    1    1    2        0    2    1    0    0    0
# 17  20  Kevin Magnussen    0    2    0        0    0    2    0    0    0
# 18   2   Logan Sargeant    0    0    0        0    0    0    0    0    0
# 19  21    Nyck de Vries    0    0    0        0    0    0    0    0    0
#
#     AUT_SPR  AUT  UK  Points
# 1         8   19  10     186
# 2         5   12   8     175
# 3         0    6  18     155
# 4         7   10   2     103
# 5         2    8  12     103
# 6         0   25   4      96
# 7         1   15  26      60
# 8         6    4   0      59
# 9         3    0   0      43
# 10        0    2   0      26
# 11        0    0  15      25
# 12        0    1   6      18
# 13        4    0   0      12
# 14        0    0   0      10
# 15        0    0   0       8
# 16        0    0   0       7
# 17        0    0   0       4
# 18        0    0   1       1
# 19        0    0   0       0

# %% [markdown]
# ### <a id='toc1_3_1_'></a>[Drivers Championship Timeline](#toc0_)

# %%
plots.drivers_timeline_plot(drivers_df)

# %% [markdown]
# ## <a id='toc1_4_'></a>[Constructors Standings After Last Race (Britain)](#toc0_)

# %%
constructors_df = utils.constructors_standings(remove_constructors,
                                               remove_drivers, last_round)
constructors_df
# Out:
#        Constructor  BAH  SAU  AUS  AZE_SPR  AZE  MIA  MON  SPA  CAN  AUT_SPR  \
# 1         Mercedes   20   27   25        9   17   25   28   43   18        2
# 2     Aston Martin   28   18   33        6   23   19   25   18   29       11
# 3          Ferrari   15   18    0       12   30   20   16   13   27        7
# 4         Red Bull   25   26   13        8   25   25    0   16   11        8
# 5          McLaren    0    0   16        0    5    0    6    0    1        1
# 6   Alpine F1 Team    4   10    0        0    0   10   26    8    6        3
# 7         Williams    2    0    0        1    0    0    0    0    8        0
# 8       Alfa Romeo    6    0    5        0    0    0    1    4    2        0
# 9     Haas F1 Team    0    2    8        0    0    2    0    0    0        4
# 10      AlphaTauri    1    1    2        0    2    1    0    0    0        0
#
#     AUT  UK  Points
# 1    14  30     258
# 2    16   8     234
# 3    35   6     199
# 4    19  10     186
# 5    15  41      85
# 6     2   0      69
# 7     1   7      19
# 8     0   0      18
# 9     0   0      16
# 10    0   0       7

# %% [markdown]
# ### <a id='toc1_4_1_'></a>[Constructors Standings Timeline](#toc0_)

# %%
plots.constructors_timeline_plot(constructors_df)
