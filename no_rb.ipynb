# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [F1 2023 without Red Bull](#toc1_)
#   - [Britain Sprint Results](#toc1_1_)
#   - [Britain Race Results](#toc1_2_)
#   - [Driver Standings After Last Race (Britain)](#toc1_3_)
#     - [Drivers Championship Timeline](#toc1_3_1_)
#   - [Constructors Standings After Last Race (Britain)](#toc1_4_)
#     - [Constructors Standings Timeline](#toc1_4_1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[F1 2023 without Red Bull](#toc0_)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utils
import plots

remove_drivers = ['VER', 'PER']
remove_constructors = ['red_bull']
last_round = 10

# %% [markdown]
# ## <a id='toc1_1_'></a>[Britain Sprint Results](#toc0_)

# %%
utils.sprint_results(remove_drivers, last_round)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## <a id='toc1_2_'></a>[Britain Race Results](#toc0_)

# %%
race_results, fastest_lap = utils.race_results(remove_drivers, last_round)
display(race_results)
utils.print_fastest_lap(fastest_lap)
# Out:
#      No           Driver     Constructor  Laps  Points
# Pos
# 1     4     Lando Norris         McLaren    52      26
# 2    44   Lewis Hamilton        Mercedes    52      18
# 3    81    Oscar Piastri         McLaren    52      15
# 4    63   George Russell        Mercedes    52      12
# 5    14  Fernando Alonso    Aston Martin    52      10
# 6    23  Alexander Albon        Williams    52       8
# 7    16  Charles Leclerc         Ferrari    52       6
# 8    55     Carlos Sainz         Ferrari    52       4
# 9     2   Logan Sargeant        Williams    52       2
# 10   77  Valtteri Bottas      Alfa Romeo    52       1
# 11   27  Nico Hülkenberg    Haas F1 Team    52       0
# 12   18     Lance Stroll    Aston Martin    52       0
# 13   24      Guanyu Zhou      Alfa Romeo    52       0
# 14   22     Yuki Tsunoda      AlphaTauri    52       0
# 15   21    Nyck de Vries      AlphaTauri    52       0
# DNF  10     Pierre Gasly  Alpine F1 Team    46       0
# ...

# %% [markdown]
# ## <a id='toc1_3_'></a>[Driver Standings After Last Race (Britain)](#toc0_)

# %%
drivers_df = utils.drivers_standings(remove_drivers, last_round)
drivers_df
# Out:
#     No           Driver  BAH  SAU  AUS  AZE_SPR  AZE  MIA  MON  SPA  CAN  \
# 1   14  Fernando Alonso   25   26   18        5   18   26   25   10   25
# 2   44   Lewis Hamilton   15   15   25        4   12   12   16   26   19
# 3   55     Carlos Sainz   18   12    2        6   15   15    6   15   12
# 4   63   George Russell   10   18    0        7    9   18   12   18    0
# 5   16  Charles Leclerc    0   10    0        8   25   10   10    2   15
# 6   18     Lance Stroll   12    0   15        3   10    1    0   12    6
# 7    4     Lando Norris    0    0   12        0    6    0    4    0    0
# 8   31     Esteban Ocon    0    8    0        0    0    6   18    8    8
# 9   10     Pierre Gasly    6    6    0        0    0    8    8    4    1
# 10  81    Oscar Piastri    0    0    8        1    2    0    2    0    2
# 11  23  Alexander Albon    4    0    0        2    1    0    0    0   10
# 12  27  Nico Hülkenberg    0    1   10        0    0    0    0    0    0
# ...

# %% [markdown]
# ### <a id='toc1_3_1_'></a>[Drivers Championship Timeline](#toc0_)

# %%
plots.drivers_timeline_plot(drivers_df)

# %% [markdown]
# ## <a id='toc1_4_'></a>[Constructors Standings After Last Race (Britain)](#toc0_)

# %%
constructors_df = utils.constructors_standings(remove_constructors,
                                               remove_drivers, last_round)
constructors_df
# Out:
#       Constructor  BAH  SAU  AUS  AZE_SPR  AZE  MIA  MON  SPA  CAN  AUT_SPR  \
# 1        Mercedes   25   33   25       11   21   30   28   44   19        4
# 2    Aston Martin   37   26   33        8   28   27   25   22   31       13
# 3         Ferrari   18   22    2       14   40   25   16   17   27        8
# 4         McLaren    0    0   20        1    8    0    6    0    2        2
# 5  Alpine F1 Team    6   14    0        0    0   14   26   12    9        4
# 6        Williams    5    0    0        2    1    0    0    0   10        0
# 7      Alfa Romeo    8    0    8        0    0    0    1    6    4        0
# 8    Haas F1 Team    0    5   10        0    0    4    0    0    0        5
# 9      AlphaTauri    2    2    4        0    4    2    0    1    0        0
#
#    AUT  UK  Points
# 1   18  30     288
# 2   21  10     281
# 3   37  10     236
# 4   18  41      98
# 5    5   0      90
# 6    2  10      30
# 7    1   1      29
# 8    0   0      24
# 9    0   0      15

# %% [markdown]
# ### <a id='toc1_4_1_'></a>[Constructors Standings Timeline](#toc0_)

# %%
plots.constructors_timeline_plot(constructors_df)
